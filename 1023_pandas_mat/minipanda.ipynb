# %%
# import openpyxl
# import pandas as pd

# wb = openpyxl.load_workbook('singer.xlsx')
# slist = wb.sheetnames
# hlist = [1,2,3,7]
# for sname in slist:
#     worksheet = wb[sname]
#     for row in range(1, worksheet.max_row + 1):
#         for col in range(1, worksheet.max_column+1):
#             if col in hlist:
#                 print("%s" %(worksheet.cell(row = row, column=col).value),end='\t')
#         print()
#     print()
# Out:
# 아이디	이름	인원	유튜브 조회수
# WMN	여자친구	6	800
# GRL	소녀시대	8	1114600
# RED	레드벨벳	4	44500
# APN	에이핑크	6	2900
# MMU	마마무	4	6900
#
# 아이디	이름	인원	유튜브 조회수
# TWC	트와이스	9	3334500
# BLK	블랙핑크	4	443700
# OMY	오마이걸	7	3500
# ITZ	있지	5	21300
# SPC	우주소녀	13	350

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt


inFilename = 'singer.xlsx'
outFilename = 'singer_over6.xlsx'

df_seniro = pd.read_excel(inFilename, 'senior',index_col=None)
df_junior = pd.read_excel(inFilename, 'junior', index_col = None)

df_singer = pd.concat([df_seniro, df_junior])
df_singer_over6 = df_singer[df_singer['인원'] >= 6]
df_singer_over6 = df_singer_over6.sort_values(by=['인원'], axis=0,ascending=False)

df_singer_over6 = df_singer_over6.loc[:,['아이디','이름','인원','유튜브 조회수']]

x_data = df_singer_over6['아이디']
y_data = df_singer_over6['인원']
colorarr = [np.random.choice(['red','green','blue','brown','gold']) for _ in range(len(x_data))]
plt.bar(x_data,y_data,color = colorarr)
plt.show()

writer = pd.ExcelWriter(outFilename)
df_singer_over6.to_excel(writer,sheet_name='singer',index=False)

writer.close()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14372\601199046.py in <module>
#       7 outFilename = 'singer_over6.xlsx'
#       8
# ----> 9 df_seniro = pd.read_excel(inFilename, 'senior',index_col=None)
#      10 df_junior = pd.read_excel(inFilename, 'junior', index_col = None)
#      11
#
# c:\Users\user\anaconda3\envs\tfgpu\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# c:\Users\user\anaconda3\envs\tfgpu\lib\site-packages\pandas\io\excel\_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, thousands, comment, skipfooter, convert_float, mangle_dupe_cols, storage_options)
#     362     if not isinstance(io, ExcelFile):
#     363         should_close = True
# --> 364         io = ExcelFile(io, storage_options=storage_options, engine=engine)
#     365     elif engine and engine != io.engine:
#     366         raise ValueError(
#
# c:\Users\user\anaconda3\envs\tfgpu\lib\site-packages\pandas\io\excel\_base.py in __init__(self, path_or_buffer, engine, storage_options)
#    1231         self.storage_options = storage_options
#    1232
# -> 1233         self._reader = self._engines[engine](self._io, storage_options=storage_options)
#    1234
#    1235     def __fspath__(self):
#
# c:\Users\user\anaconda3\envs\tfgpu\lib\site-packages\pandas\io\excel\_openpyxl.py in __init__(self, filepath_or_buffer, storage_options)
#     519             passed to fsspec for appropriate URLs (see ``_get_filepath_or_buffer``)
#     520         """
# --> 521         import_optional_dependency("openpyxl")
#     522         super().__init__(filepath_or_buffer, storage_options=storage_options)
#     523
#
# c:\Users\user\anaconda3\envs\tfgpu\lib\site-packages\pandas\compat\_optional.py in import_optional_dependency(name, extra, errors, min_version)
#     116     except ImportError:
#     117         if errors == "raise":
# --> 118             raise ImportError(msg) from None
#     119         else:
#     120             return None
#
# ImportError: Missing optional dependency 'openpyxl'.  Use pip or conda to install openpyxl.

# %%
inFilename = 'singer.xlsx'
SIZE = 30
df_seniro = pd.read_excel(inFilename, 'senior',index_col=None)
df_junior = pd.read_excel(inFilename, 'junior', index_col = None)

df_singer = pd.concat([df_seniro, df_junior])
df_singer_over6 = df_singer.sort_values(by=['유튜브 조회수'], axis=0,ascending=False)
df_singer_over6 = df_singer_over6.loc[:,['아이디','이름','인원','유튜브 조회수']]

x_data = df_singer_over6['아이디']
y_data = df_singer_over6['유튜브 조회수']
sizearr = np.sqrt(df_singer_over6['유튜브 조회수'])
colorarr = np.random.rand(len(x_data))

plt.scatter(x_data,y_data,s=sizearr,c=colorarr,alpha = 0.5, cmap = 'winter')
plt.show()

# %%
inFilename = 'singer.xlsx'
SIZE = 30
df_seniro = pd.read_excel(inFilename, 'senior',index_col=None)
df_junior = pd.read_excel(inFilename, 'junior', index_col = None)

df_singer = pd.concat([df_seniro, df_junior])
df_singer_over6 = df_singer.sort_values(by=['유튜브 조회수'], axis=0,ascending=False)
df_singer_over6 = df_singer_over6.loc[:,['아이디','이름','인원','유튜브 조회수']]

x_data = df_singer_over6['아이디']
y_data = df_singer_over6['유튜브 조회수']
sizearr = np.sqrt(df_singer_over6['유튜브 조회수'])
colorarr = [np.random.choice(['red','green','blue','brown','gold']) for _ in range(len(x_data))]

plt.bar(x_data,y_data,color = colorarr)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14372\3791502760.py in <module>
#       1 inFilename = 'singer.xlsx'
#       2 SIZE = 30
# ----> 3 df_seniro = pd.read_excel(inFilename, 'senior',index_col=None)
#       4 df_junior = pd.read_excel(inFilename, 'junior', index_col = None)
#       5
#
# c:\Users\user\anaconda3\envs\tfgpu\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# c:\Users\user\anaconda3\envs\tfgpu\lib\site-packages\pandas\io\excel\_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, thousands, comment, skipfooter, convert_float, mangle_dupe_cols, storage_options)
#     362     if not isinstance(io, ExcelFile):
#     363         should_close = True
# --> 364         io = ExcelFile(io, storage_options=storage_options, engine=engine)
#     365     elif engine and engine != io.engine:
#     366         raise ValueError(
#
# c:\Users\user\anaconda3\envs\tfgpu\lib\site-packages\pandas\io\excel\_base.py in __init__(self, path_or_buffer, engine, storage_options)
#    1231         self.storage_options = storage_options
#    1232
# -> 1233         self._reader = self._engines[engine](self._io, storage_options=storage_options)
#    1234
#    1235     def __fspath__(self):
#
# c:\Users\user\anaconda3\envs\tfgpu\lib\site-packages\pandas\io\excel\_openpyxl.py in __init__(self, filepath_or_buffer, storage_options)
#     519             passed to fsspec for appropriate URLs (see ``_get_filepath_or_buffer``)
#     520         """
# --> 521         import_optional_dependency("openpyxl")
#     522         super().__init__(filepath_or_buffer, storage_options=storage_options)
#     523
#
# c:\Users\user\anaconda3\envs\tfgpu\lib\site-packages\pandas\compat\_optional.py in import_optional_dependency(name, extra, errors, min_version)
#     116     except ImportError:
#     117         if errors == "raise":
# --> 118             raise ImportError(msg) from None
#     119         else:
#     120             return None
#
# ImportError: Missing optional dependency 'openpyxl'.  Use pip or conda to install openpyxl.
