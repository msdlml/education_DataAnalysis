# %%
#실습 무식하게 하기 ㅋㅋ
import csv
import glob
import os

flist = glob.glob(os.path.join('*.csv'))

firstYN = True
with open("popul1960.csv","r",encoding="euc-kr") as inFpA:
    with open("popul1970.csv","r",encoding="euc-kr") as inFpB:
        with open("popul1980.csv","r",encoding="euc-kr") as inFpC:
            with open("popul1990.csv","r",encoding="euc-kr") as inFpD:
                with open("popul2000.csv","r",encoding="euc-kr") as inFpE:
                    with open("popul2010.csv","r",encoding="euc-kr") as inFpF:
                        with open("강원인구통합.csv","w",encoding="euc-kr") as outFp:
                            csvRa = csv.reader(inFpA)
                            csvRb = csv.reader(inFpB)
                            csvRc = csv.reader(inFpC)
                            csvRd = csv.reader(inFpD)
                            csvRe = csv.reader(inFpE)
                            csvRf = csv.reader(inFpF)
                            csvwr = csv.writer(outFp)
                            head_list = next(csvRa)
                            head_list = next(csvRb)
                            head_list = next(csvRc)
                            head_list = next(csvRd)
                            head_list = next(csvRe)
                            head_list = next(csvRf)
                            print(head_list)
                            csvwr.writerow(head_list)

                            for row_list in csvRa:
                                print(row_list)
                                csvwr.writerow(row_list)
                            for row_list in csvRb:
                                print(row_list)
                                csvwr.writerow(row_list)
                            for row_list in csvRc:
                                print(row_list)
                                csvwr.writerow(row_list)
                            for row_list in csvRd:
                                print(row_list)
                                csvwr.writerow(row_list)
                            for row_list in csvRe:
                                print(row_list)
                                csvwr.writerow(row_list)
                            for row_list in csvRf:
                                print(row_list)
                                csvwr.writerow(row_list)
# Out:
# ['시점', '세대수', '인구수', '남자인구', '여자인구', '한국인인구', '한국인남자', '한국인여자', '외국인인구', '외국인남자', '외국인여자']
# ['1961', '296732', '1585869', '791267', '794602', '', '', '', '', '', '']
# ['1962', '295754', '1593037', '808319', '784718', '1593037', '', '', '', '', '']
# ['1963', '305792', '1678126', '852652', '825474', '1678126', '852652', '825474', '0', '', '']
# ['1964', '308605', '1722005', '878558', '843447', '1722005', '878558', '843447', '0', '', '']
# ['1965', '312688', '1771035', '902167', '868868', '1771035', '902167', '868868', '0', '0', '0']
# ['1966', '334196', '1832383', '936824', '895559', '1832383', '936824', '895559', '0', '0', '0']
# ['1967', '326508', '1825018', '930319', '894699', '1825018', '930319', '894699', '0', '0', '0']
# ['1968', '325301', '1823612', '928804', '894808', '1823612', '928804', '894808', '0', '0', '0']
# ['1969', '328938', '1810527', '924250', '886277', '1810527', '924250', '886277', '0', '0', '0']
# ...

# %%
import csv
import glob
import os

flist = glob.glob(os.path.join('*.csv'))

firstYN = True

for input_file in flist:
    print(input_file)
    with open(input_file,"r",encoding="euc-kr") as inFp:
        with open("강원인구통합.csv", "a", newline='',encoding="euc-kr") as outFp:
            csvR = csv.reader(inFp)
            csvwr = csv.writer(outFp)
            header_list = next(csvR)

            if firstYN == True:
                csvwr.writerow(header_list)
                firstYN = False
            
            for row_list in csvR:
                csvwr.writerow(row_list)
# Out:
# popul1960.csv
# popul1970.csv
# popul1980.csv
# popul1990.csv
# popul2000.csv
# popul2010.csv
